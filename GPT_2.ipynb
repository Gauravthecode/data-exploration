# %% [markdown]
# <a href="https://colab.research.google.com/github/saitama8mychicken/data-exploration/blob/master/GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup:
#
# 1) Make sure GPU is enabled, go to edit->notebook settings->Hardware Accelerator GPU
#
# 2) make a copy to your google drive, click on copy to drive in panel

# %% [markdown]
# Note: colab will reset after 12 hours make sure to save your model checkpoints to google drive around 10-11 hours mark or before, then go to runtime->reset all runtimes. Now copy your train model back into colab and start training again from the previous checkpoint.

# %% [markdown]
# clone and cd into repo

# %%
# !git clone https://github.com/nshepperd/gpt-2.git
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 297, done.
# remote: Total 297 (delta 0), reused 0 (delta 0), pack-reused 297
# Receiving objects: 100% (297/297), 4.40 MiB | 3.77 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
cd gpt-2
# Out:
# /content/gpt-2

# %% [markdown]
# install requirements

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting fire>=0.1.3 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5a/b7/205702f348aab198baecd1d8344a90748cb68f53bdcd1cc30cbc08e47d3e/fire-0.1.3.tar.gz
# Collecting regex==2017.4.5 (from -r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#      |████████████████████████████████| 604kB 40.8MB/s
# Requirement already satisfied: requests==2.21.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (2.21.0)
# Collecting tqdm==4.31.1 (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 27.5MB/s
# Collecting toposort==1.5 (from -r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/2a/1a/4d/6b30377c3051e76559d1185c1dbbfff15aed31f87acdd14c22
#   Building wheel for regex (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# ERROR: spacy 2.0.18 has requirement regex==2018.01.10, but you'll have regex 2017.4.5 which is incompatible.
# Installing collected packages: fire, regex, tqdm, toposort
#   Found existing installation: regex 2018.1.10
#     Uninstalling regex-2018.1.10:
#       Successfully uninstalled regex-2018.1.10
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# Successfully installed fire-0.1.3 regex-2017.4.5 toposort-1.5 tqdm-4.31.1

# %% [markdown]
# mount drive to access google drive for saving and accessing checkpoints later

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     182       # Not already authorized, so do the authorization dance.
#     183       auth_prompt = d.match.group(1) + '\n\nEnter your authorization code:\n'
# --> 184       d.send(_getpass.getpass(auth_prompt) + '\n')
#     185   d.sendcontrol('z')
#     186   d.expect(u'Stopped')
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     686             self._parent_ident,
#     687             self._parent_header,
# --> 688             password=True,
#     689         )
#     690
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %% [markdown]
# download the model

# %%
# !python3 download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 791kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 53.5Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 595kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:08, 57.5Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 3.45Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 46.8Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 48.7Mit/s]

# %%
# !export PYTHONIOENCODING=UTF-8

# %% [markdown]
# fetch checkpoints if you have them saved in google drive

# %%
# !cp -r /content/drive/My\ Drive/checkpoint/ /content/gpt-2/

# %% [markdown]
# lets get our text to train on, in this case from project gutenberg, A Tale of Two Cities, by Charles Dickens

# %%
#ToTC
# !wget https://www.gutenberg.org/files/98/98-0.txt

# %%
#DRACULA
# !wget http://www.gutenberg.org/ebooks/345.txt.utf-8

# %%
#SUPERHERO BIOS
# !wget http://www.cc.gatech.edu/~riedl/origin
# Out:
# --2019-06-04 23:40:08--  http://www.cc.gatech.edu/~riedl/origin
# Resolving www.cc.gatech.edu (www.cc.gatech.edu)... 130.207.7.210
# Connecting to www.cc.gatech.edu (www.cc.gatech.edu)|130.207.7.210|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cc.gatech.edu/~riedl/origin [following]
# --2019-06-04 23:40:09--  https://www.cc.gatech.edu/~riedl/origin
# Connecting to www.cc.gatech.edu (www.cc.gatech.edu)|130.207.7.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154415 (151K) [text/plain]
# Saving to: ‘origin’
#
# origin              100%[===================>] 150.80K   208KB/s    in 0.7s
#
# 2019-06-04 23:40:10 (208 KB/s) - ‘origin’ saved [154415/154415]

# %% [markdown]
# start training

# %%
#ToTC
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2/98-0.txt

# %%
#DRACULA
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2/345.txt.utf-8

# %%
#SUPERHERO BIOS
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2/origin
# Out:
# 2019-06-04 23:40:24.396310: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-06-04 23:40:24.396735: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2081700 executing computations on platform Host. Devices:
# 2019-06-04 23:40:24.396774: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-04 23:40:24.656911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-04 23:40:24.657518: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2081440 executing computations on platform CUDA. Devices:
# 2019-06-04 23:40:24.657549: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-06-04 23:40:24.657968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.60GiB
# 2019-06-04 23:40:24.658013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-04 23:40:26.014945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-04 23:40:26.015023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-04 23:40:26.015035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-04 23:40:26.015383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14115 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Loading checkpoint models/117M/model.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading dataset...
# 100% 1/1 [00:00<00:00,  2.44it/s]
# dataset has 34628 tokens
# Training...
# 2019-06-04 23:40:47.135119: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1 | 4.34] loss=3.38 avg=3.38
# [2 | 4.81] loss=3.41 avg=3.39
# [3 | 5.26] loss=3.55 avg=3.45
# [4 | 5.73] loss=3.59 avg=3.48
# [5 | 6.19] loss=3.59 avg=3.50
# [6 | 6.65] loss=3.42 avg=3.49
# [7 | 7.11] loss=3.50 avg=3.49
# [8 | 7.57] loss=3.27 avg=3.46
# [9 | 8.03] loss=3.36 avg=3.45
# [10 | 8.49] loss=3.17 avg=3.42
# [11 | 8.96] loss=3.67 avg=3.44
# [12 | 9.42] loss=3.32 avg=3.43
# [13 | 9.88] loss=3.41 avg=3.43
# [14 | 10.35] loss=3.27 avg=3.42
# [15 | 10.81] loss=3.16 avg=3.40
# [16 | 11.28] loss=3.35 avg=3.40
# [17 | 11.74] loss=3.36 avg=3.40
# [18 | 12.21] loss=3.36 avg=3.39
# [19 | 12.67] loss=3.35 avg=3.39
# [20 | 13.13] loss=3.37 avg=3.39
# [21 | 13.60] loss=3.00 avg=3.37
# [22 | 14.07] loss=3.39 avg=3.37
# [23 | 14.53] loss=3.05 avg=3.35
# [24 | 15.00] loss=3.27 avg=3.35
# [25 | 15.46] loss=3.31 avg=3.35
# [26 | 15.93] loss=3.28 avg=3.35
# [27 | 16.39] loss=3.01 avg=3.33
# [28 | 16.86] loss=3.19 avg=3.33
# [29 | 17.33] loss=3.32 avg=3.33
# [30 | 17.80] loss=3.34 avg=3.33
# [31 | 18.27] loss=3.43 avg=3.33
# [32 | 18.74] loss=3.34 avg=3.33
# [33 | 19.21] loss=3.04 avg=3.32
# [34 | 19.67] loss=3.24 avg=3.32
# [35 | 20.14] loss=3.01 avg=3.31
# [36 | 20.61] loss=3.34 avg=3.31
# [37 | 21.09] loss=2.88 avg=3.29
# [38 | 21.56] loss=3.13 avg=3.29
# [39 | 22.03] loss=3.20 avg=3.29
# [40 | 22.50] loss=3.23 avg=3.29
# [41 | 22.97] loss=3.49 avg=3.29
# [42 | 23.44] loss=3.18 avg=3.29
# [43 | 23.91] loss=3.33 avg=3.29
# [44 | 24.38] loss=3.22 avg=3.29
# [45 | 24.86] loss=3.26 avg=3.29
# [46 | 25.33] loss=3.19 avg=3.28
# [47 | 25.80] loss=2.85 avg=3.27
# [48 | 26.28] loss=2.89 avg=3.26
# [49 | 26.75] loss=3.11 avg=3.26
# [50 | 27.23] loss=3.10 avg=3.25
# [51 | 27.70] loss=2.87 avg=3.24
# [52 | 28.17] loss=3.23 avg=3.24
# [53 | 28.65] loss=3.28 avg=3.25
# [54 | 29.12] loss=3.13 avg=3.24
# [55 | 29.60] loss=3.39 avg=3.25
# [56 | 30.07] loss=3.20 avg=3.24
# [57 | 30.55] loss=3.07 avg=3.24
# [58 | 31.02] loss=2.73 avg=3.23
# [59 | 31.50] loss=3.20 avg=3.23
# [60 | 31.98] loss=3.09 avg=3.23
# [61 | 32.45] loss=3.07 avg=3.22
# [62 | 32.93] loss=3.32 avg=3.22
# [63 | 33.41] loss=3.21 avg=3.22
# [64 | 33.89] loss=3.01 avg=3.22
# [65 | 34.36] loss=3.26 avg=3.22
# [66 | 34.84] loss=3.43 avg=3.22
# [67 | 35.32] loss=3.39 avg=3.23
# [68 | 35.80] loss=2.87 avg=3.22
# [69 | 36.28] loss=3.07 avg=3.22
# [70 | 36.76] loss=2.95 avg=3.21
# [71 | 37.24] loss=3.03 avg=3.21
# [72 | 37.72] loss=3.32 avg=3.21
# [73 | 38.20] loss=3.03 avg=3.21
# [74 | 38.68] loss=3.23 avg=3.21
# [75 | 39.16] loss=2.92 avg=3.20
# [76 | 39.65] loss=2.88 avg=3.20
# [77 | 40.13] loss=3.06 avg=3.19
# [78 | 40.61] loss=3.04 avg=3.19
# [79 | 41.10] loss=3.04 avg=3.19
# [80 | 41.58] loss=2.62 avg=3.18
# [81 | 42.07] loss=3.04 avg=3.18
# [82 | 42.56] loss=2.97 avg=3.17
# [83 | 43.04] loss=3.13 avg=3.17
# [84 | 43.53] loss=2.88 avg=3.17
# [85 | 44.02] loss=2.68 avg=3.16
# [86 | 44.50] loss=2.78 avg=3.15
# [87 | 44.99] loss=3.38 avg=3.15
# [88 | 45.48] loss=2.71 avg=3.15
# [89 | 45.97] loss=2.82 avg=3.14
# [90 | 46.46] loss=2.53 avg=3.13
# [91 | 46.95] loss=2.88 avg=3.13
# [92 | 47.44] loss=3.12 avg=3.13
# [93 | 47.93] loss=3.21 avg=3.13
# [94 | 48.42] loss=2.83 avg=3.12
# [95 | 48.91] loss=2.83 avg=3.12
# [96 | 49.40] loss=2.81 avg=3.11
# [97 | 49.89] loss=3.15 avg=3.11
# [98 | 50.38] loss=3.15 avg=3.11
# [99 | 50.87] loss=2.73 avg=3.11
# Generating samples...
# ======== SAMPLE 1 ========
# icity.
# They were joined by a young lady named "She" named after her sister.
# She is sent back in time where the boy's father was murdered and she was taken into an alternate dimension where the world was a different place.
# She met Maxima, a young girl from the '50s who was raised in the same school.
# She later developed psychic powers and became friends with the original Maxima, though they became more distant when Maxima's son was killed in a shootout.
# She went on to become the first hero of the '90s.
# They are joined during his 'supernatural' time by his first love, Jeanette.
# They later split, with Jeanette going by some later name.
# Later she rekindles their friendship.
# Eventually a battle with the Man in the High Castle brings them back to the present and allows the Man in the High Castle to save them.
# He is saved by a small gang of members called the Night's Watch.
# They attempt to get in contact with the Man in the High Castle, which is destroyed by a new force.
# This force, named the World's Finest, kills several members of the Night's Watch.
# It is revealed that the Man in the High Castle was also a hero of a past that is about as old as time itself.
# The Night's Watch were joined by Doctor Strange, who helped the Man in the High Castle on a mission called The Avengers' Last Stand.
# Doctor Strange has gained access to a powerful alien force known as the Eternal Force and is trying to use them to manipulate the Night's Watch into doing things that he would have considered to be insane.
# However, when Doctor Strange realizes the Eternal Force are secretly implanted in his mind, he starts realizing that they are also the true heroes.
# The Eternal Force then sends all of them back in time (with Maxima joining to stop her) to prevent Doctor Strange from stopping his own team from being killed.
# But, while in his time, she is not at all involved with the battle between Doctor Strange and the Eternal Force (because she was never really supposed to be involved).
# She was also there during the battle with the Eternal Force.
# She helped Doctor Strange to avenge and rescue the girl (Jeanette).
# Doctor Strange, having lost contact with his friends before, goes on to find out who his team were during this time.
# He has a confrontation with Jeanette, but only in her place of absence until she recovers in time to save him, and then reveals that she is the daughter of the father of the girl, Maxima.
# Doctor Strange, who then goes by the name of Doctor Doom, tells her that he will not be returning his sister's life to him to cause the death of the entire Man in the High Castle.
# He also tells her that Maxima is his true self, one who lives by love and a code where he is always ready to die to save a hero.
# He is willing to pay for his sister's death for his own (as opposed to any hero's sacrifice for the cause) and leaves her with the Eternal Force, while keeping his current team members alive and well.
# He also kills all of the Night's Watch members with the Eternal Force.
# As a result, the Night's Watch cannot be contacted anymore and the Eternal Force is disbanded.
# The Eternal Force then turns itself back on the young girl in order to protect her child and give Doctor Strange power over the Eternal Force.
# When Maxima disappears, this power is used against her at the final moment when the Eternal Force reappears.
# To save a boy, the Eternal Force takes the form of a single man and the child then dies, and the man is turned into an Immortal Man and the Eternal Force gives the boy the power to see the light of his soul, as Maxima did.
# However, the Eternal Force also allows Maxima to become possessed at some point during the story, where she becomes a Vampire, but after this, the Eternal Force disappears as well.
# During Maxima's story, she becomes the wife of Dr. Octopus' wife Mabel.
# During her time in the Eternal Force, Maxima was actually killed by the Living Dragon, the god of death.
# The Living Dragon took her from Maxima, turned her into a monster and attacked her with its own hands.
# When the Living Dragon turned her back on her husband, Maxima would only leave his side, telling him that she would never forgive Doctor Strange for what had happened to her while he also wanted him to leave his best friend as his first wife.
# However, upon learning of his death, she broke off her relationship with him and left the Eternal Force after doing so.
# She left the Eternal Force to find another husband who would lead her to her true self, where she would leave him behind and come on in life with her best friend who would go on to find the man she had chosen in such a life
#
# [100 | 64.04] loss=3.04 avg=3.11
# [101 | 64.53] loss=2.87 avg=3.10
# [102 | 65.02] loss=3.01 avg=3.10
# [103 | 65.51] loss=3.02 avg=3.10
# [104 | 66.00] loss=3.01 avg=3.10
# [105 | 66.49] loss=2.47 avg=3.09
# [106 | 66.98] loss=2.72 avg=3.08
# [107 | 67.47] loss=3.21 avg=3.09
# [108 | 67.96] loss=2.63 avg=3.08
# [109 | 68.44] loss=3.12 avg=3.08
# [110 | 68.93] loss=3.32 avg=3.08
# [111 | 69.41] loss=2.87 avg=3.08
# [112 | 69.90] loss=2.58 avg=3.07
# [113 | 70.38] loss=3.00 avg=3.07
# [114 | 70.87] loss=2.70 avg=3.07
# [115 | 71.35] loss=2.86 avg=3.06
# [116 | 71.83] loss=2.53 avg=3.06
# [117 | 72.31] loss=2.45 avg=3.05
# [118 | 72.80] loss=2.80 avg=3.04
# [119 | 73.28] loss=2.87 avg=3.04
# [120 | 73.76] loss=2.99 avg=3.04
# [121 | 74.24] loss=3.01 avg=3.04
# [122 | 74.72] loss=2.89 avg=3.04
# [123 | 75.21] loss=3.11 avg=3.04
# [124 | 75.69] loss=2.84 avg=3.04
# [125 | 76.17] loss=3.00 avg=3.04
# [126 | 76.65] loss=2.97 avg=3.03
# [127 | 77.13] loss=2.84 avg=3.03
# [128 | 77.61] loss=2.92 avg=3.03
# [129 | 78.09] loss=2.69 avg=3.03
# [130 | 78.57] loss=2.91 avg=3.02
# [131 | 79.05] loss=2.90 avg=3.02
# [132 | 79.53] loss=2.90 avg=3.02
# [133 | 80.01] loss=2.81 avg=3.02
# [134 | 80.49] loss=2.82 avg=3.02
# [135 | 80.97] loss=2.74 avg=3.01
# [136 | 81.45] loss=2.98 avg=3.01
# [137 | 81.93] loss=2.97 avg=3.01
# [138 | 82.41] loss=3.11 avg=3.01
# [139 | 82.89] loss=2.81 avg=3.01
# [140 | 83.37] loss=2.79 avg=3.01
# [141 | 83.85] loss=2.96 avg=3.01
# [142 | 84.33] loss=3.02 avg=3.01
# [143 | 84.80] loss=2.87 avg=3.00
# [144 | 85.28] loss=2.96 avg=3.00
# [145 | 85.76] loss=2.65 avg=3.00
# [146 | 86.24] loss=2.77 avg=3.00
# [147 | 86.71] loss=2.48 avg=2.99
# [148 | 87.19] loss=2.92 avg=2.99
# [149 | 87.67] loss=2.83 avg=2.99
# [150 | 88.15] loss=2.61 avg=2.98
# [151 | 88.63] loss=2.75 avg=2.98
# [152 | 89.11] loss=2.62 avg=2.97
# [153 | 89.58] loss=2.69 avg=2.97
# [154 | 90.06] loss=2.88 avg=2.97
# [155 | 90.54] loss=2.48 avg=2.96
# [156 | 91.01] loss=2.35 avg=2.96
# [157 | 91.49] loss=2.86 avg=2.95
# [158 | 91.97] loss=2.74 avg=2.95
# [159 | 92.45] loss=2.75 avg=2.95
# [160 | 92.92] loss=2.57 avg=2.94
# [161 | 93.40] loss=2.67 avg=2.94
# [162 | 93.87] loss=2.70 avg=2.94
# [163 | 94.35] loss=2.72 avg=2.94
# [164 | 94.83] loss=2.39 avg=2.93
# [165 | 95.31] loss=2.37 avg=2.92
# [166 | 95.79] loss=2.38 avg=2.91
# [167 | 96.26] loss=2.76 avg=2.91
# [168 | 96.74] loss=2.90 avg=2.91
# [169 | 97.22] loss=2.42 avg=2.91
# [170 | 97.69] loss=2.17 avg=2.90
# [171 | 98.17] loss=2.63 avg=2.89
# [172 | 98.65] loss=2.92 avg=2.89
# [173 | 99.13] loss=2.56 avg=2.89
# [174 | 99.61] loss=2.38 avg=2.88
# [175 | 100.08] loss=2.62 avg=2.88
# [176 | 100.56] loss=2.42 avg=2.88
# [177 | 101.04] loss=2.23 avg=2.87
# [178 | 101.52] loss=2.43 avg=2.86
# [179 | 101.99] loss=2.75 avg=2.86
# [180 | 102.47] loss=2.69 avg=2.86
# [181 | 102.95] loss=2.60 avg=2.86
# [182 | 103.42] loss=2.53 avg=2.85
# [183 | 103.91] loss=2.92 avg=2.85
# [184 | 104.38] loss=2.50 avg=2.85
# [185 | 104.86] loss=2.60 avg=2.85
# [186 | 105.34] loss=2.57 avg=2.84
# [187 | 105.82] loss=2.18 avg=2.83
# [188 | 106.30] loss=2.82 avg=2.83
# [189 | 106.77] loss=2.21 avg=2.83
# [190 | 107.25] loss=2.08 avg=2.82
# [191 | 107.73] loss=2.81 avg=2.82
# [192 | 108.21] loss=2.52 avg=2.82
# [193 | 108.69] loss=2.48 avg=2.81
# [194 | 109.16] loss=2.62 avg=2.81
# [195 | 109.64] loss=2.47 avg=2.81
# [196 | 110.12] loss=2.52 avg=2.80
# [197 | 110.60] loss=2.41 avg=2.80
# [198 | 111.08] loss=3.07 avg=2.80
# [199 | 111.56] loss=2.58 avg=2.80
# Generating samples...
# ======== SAMPLE 1 ========
#  Cyborg, and the only person who's been able to stop the supernova is the Emperor.
# The Emperor has previously interfered with this storyline with his return from space when, after an epic battle with the Time Queen, Luke Skywalker defeats the Time Lords and reveals that he's been replaced by an evil Force-hungry tyrant, the Emperor.
# Luke leaves the Force in an attempt to return to his own universe, only to fall victim to the mind control of his new "super-human" sidekick, Namor.
# He then gains a close personal friendship with an old foe, Professor X and departs the Star Tours show with his team, while Lady Fury plots to kill him.
# The next storyline reveals the Emperor has also interfered with the Star Wars storyline by altering the course of Star Wars history, altering the origin story of Solo into a parallel universe (with the former being changed into a parallel universe to him by Tarkin during the second intergalactic skirmish), altering the hero's identity from a minor hero to an Imperial super genius, altering his mind, and altering his identity as Solo in a series of secret orders.
# This final storyline also details a series of secret missions within Star Wars by members of the First Order.
# In the alternate realities, the Great One, General Hux and the Emperor, with Hux's intervention possibly being a foreshadowing, have been able to create "World of Warcraft".
# In the original version of the two-part series, Hux, who has been killed, becomes the sole surviving member of the Great One's organization, the Wildling.
# Before long, his body is discovered in the Savage Land, a vast and mystical jungle dominated by enormous monsters—one in which Hux was killed.
# Before he dies, Hux is buried at Mount Hymn of the Gods, and the other members, most notably the original Master Hix, turn on him.
# Some of the other member deaths are apparently due to Hux's fall from grace, though there is no indication what the cause was.
# The "worlds of Warcraft" storyline originally ran from December 20, 2010 until July 6, 2012.
# At the end of her tenure as the Great One, she publicly revealed the secret orders that kept her from becoming the next Great One, and the other members of the Great One were replaced with new members—including a third, seemingly self-appointed leader known only as the "Great Mother" who has recently escaped from Mount Hymn of the Gods.
# In 2013, Blizzard revealed that there would be much more to the World of Warcraft storyline.
# The official announcement that was made was in response to a question on Twitter about the decision by the team at CCP, Blizzard Entertainment, and Hux to change stories, and the team explain the current state of affairs in Star Wars, The West Wing universe and other Star Wars movies.
# Shortly after, a group of members of Star Wars Studios, including John Williams, shared a post on a popular Star Wars forum with a series of questions:
# How can Star Wars actors improve their story as they return from their own world of crime and chaos?
# What are the benefits of casting actors from Star Wars who have traveled throughout the galaxy and are still finding their footing, such as a "bad guy" who is able to control and manipulate his or her actions and powers while hiding those powers from others?
# Why should Star Wars actors be the target of a false flag attempt to manipulate the characters to their own ends, such as by creating a fictional world containing real Star Wars characters, and keeping his or her real friends, allies, enemies and worlds from him.
# What should actors do instead in a world that has not yet been created or is currently in a virtual or artificial state of affairs where all of the characters are actors who need to be killed to preserve their own stories and identities?
# While casting actors might be able to play actors, casting actors do not own Star Wars or the characters it casts, and actors who are acting with one is a false flag to be believed.
# This leaves a casting question: what is the benefit or lack of benefit of casting actors or the effects of casting actors on the characters, universe and characters that they create (e.g., as an acting character, a rogue who is able to cause chaos via his knowledge, power and influence, or as an intergalactic foe or hero)?
# It is clear that casting actors are able to create worlds that are never seen alive and that these worlds have many, many heroes.
# However, casting actors might well be willing to allow their own characters, environments and worlds to be changed in ways that allow their own characters to appear in ways that serve their own entertainment properties.
# Although Star Wars actors might be able to make their own world and characters that are realistic and realistic, casting directors would still have to use Star Wars technology and technology to make the world look good, because casts would not be able to produce actual "worlds" that would actually be
#
# [200 | 123.39] loss=2.61 avg=2.80
# [201 | 123.88] loss=2.36 avg=2.79
# [202 | 124.36] loss=2.79 avg=2.79
# [203 | 124.84] loss=2.63 avg=2.79
# [204 | 125.33] loss=2.30 avg=2.78
# [205 | 125.81] loss=2.12 avg=2.78
# [206 | 126.29] loss=2.64 avg=2.77
# [207 | 126.77] loss=2.52 avg=2.77
# [208 | 127.26] loss=2.50 avg=2.77
# [209 | 127.74] loss=2.34 avg=2.76
# [210 | 128.22] loss=2.58 avg=2.76
# [211 | 128.71] loss=2.52 avg=2.76
# [212 | 129.19] loss=2.37 avg=2.75
# [213 | 129.67] loss=2.41 avg=2.75
# [214 | 130.16] loss=2.00 avg=2.74
# [215 | 130.64] loss=2.49 avg=2.74
# [216 | 131.12] loss=2.74 avg=2.74
# [217 | 131.60] loss=2.63 avg=2.74
# [218 | 132.09] loss=2.53 avg=2.74
# [219 | 132.58] loss=2.52 avg=2.73
# [220 | 133.06] loss=1.94 avg=2.72
# [221 | 133.54] loss=2.52 avg=2.72
# [222 | 134.02] loss=2.47 avg=2.72
# [223 | 134.51] loss=2.21 avg=2.71
# [224 | 134.99] loss=2.21 avg=2.71
# [225 | 135.47] loss=2.16 avg=2.70
# [226 | 135.96] loss=2.33 avg=2.70
# [227 | 136.44] loss=2.62 avg=2.70
# [228 | 136.93] loss=2.49 avg=2.69
# [229 | 137.41] loss=2.02 avg=2.69
# [230 | 137.89] loss=2.25 avg=2.68
# [231 | 138.37] loss=2.43 avg=2.68
# [232 | 138.85] loss=2.53 avg=2.68
# [233 | 139.34] loss=2.70 avg=2.68
# [234 | 139.82] loss=2.47 avg=2.68
# [235 | 140.30] loss=1.80 avg=2.67
# [236 | 140.78] loss=2.29 avg=2.66
# [237 | 141.27] loss=2.58 avg=2.66
# [238 | 141.75] loss=2.14 avg=2.65
# [239 | 142.24] loss=2.38 avg=2.65
# [240 | 142.72] loss=2.57 avg=2.65
# [241 | 143.20] loss=2.17 avg=2.65
# [242 | 143.68] loss=2.05 avg=2.64
# [243 | 144.17] loss=2.45 avg=2.64
# [244 | 144.65] loss=2.16 avg=2.63
# [245 | 145.13] loss=1.82 avg=2.62
# [246 | 145.61] loss=2.60 avg=2.62
# [247 | 146.10] loss=2.22 avg=2.62
# [248 | 146.58] loss=1.97 avg=2.61
# [249 | 147.06] loss=2.10 avg=2.61
# [250 | 147.54] loss=2.34 avg=2.60
# [251 | 148.03] loss=2.29 avg=2.60
# [252 | 148.51] loss=2.51 avg=2.60
# [253 | 148.99] loss=2.13 avg=2.59
# [254 | 149.48] loss=2.23 avg=2.59
# [255 | 149.97] loss=2.33 avg=2.59
# [256 | 150.45] loss=1.83 avg=2.58
# [257 | 150.94] loss=2.31 avg=2.58
# [258 | 151.42] loss=2.12 avg=2.57
# [259 | 151.90] loss=2.49 avg=2.57
# [260 | 152.38] loss=2.41 avg=2.57
# [261 | 152.86] loss=1.91 avg=2.56
# [262 | 153.35] loss=2.28 avg=2.56
# [263 | 153.83] loss=2.29 avg=2.56
# [264 | 154.31] loss=1.79 avg=2.55
# [265 | 154.79] loss=2.26 avg=2.54
# [266 | 155.28] loss=2.15 avg=2.54
# [267 | 155.76] loss=1.72 avg=2.53
# [268 | 156.24] loss=2.75 avg=2.53
# [269 | 156.72] loss=2.23 avg=2.53
# [270 | 157.20] loss=1.62 avg=2.52
# [271 | 157.69] loss=2.24 avg=2.52
# [272 | 158.16] loss=1.97 avg=2.51
# [273 | 158.65] loss=1.96 avg=2.51
# [274 | 159.13] loss=2.22 avg=2.50
# [275 | 159.61] loss=2.04 avg=2.50
# [276 | 160.10] loss=1.98 avg=2.49
# [277 | 160.58] loss=2.17 avg=2.49
# [278 | 161.06] loss=2.15 avg=2.48
# [279 | 161.54] loss=1.76 avg=2.48
# [280 | 162.03] loss=2.07 avg=2.47
# [281 | 162.51] loss=2.39 avg=2.47
# [282 | 162.99] loss=2.49 avg=2.47
# [283 | 163.47] loss=1.83 avg=2.47
# [284 | 163.95] loss=2.03 avg=2.46
# [285 | 164.44] loss=2.13 avg=2.46
# [286 | 164.92] loss=2.13 avg=2.45
# [287 | 165.40] loss=1.95 avg=2.45
# [288 | 165.88] loss=1.78 avg=2.44
# [289 | 166.36] loss=2.00 avg=2.44
# [290 | 166.85] loss=1.93 avg=2.43
# [291 | 167.33] loss=1.50 avg=2.42
# [292 | 167.81] loss=2.12 avg=2.42
# [293 | 168.29] loss=1.48 avg=2.41
# [294 | 168.77] loss=1.77 avg=2.40
# [295 | 169.25] loss=1.85 avg=2.40
# [296 | 169.73] loss=1.93 avg=2.39
# [297 | 170.21] loss=1.80 avg=2.38
# [298 | 170.69] loss=1.90 avg=2.38
# [299 | 171.17] loss=1.80 avg=2.37
# Generating samples...
# ======== SAMPLE 1 ========
#  discover a connection between the heroes, with Diana and Thor seemingly operating under the alias of the Crimson Queen who previously ruled before her.
# When their battle against the Dark Gods began, Oracle, Psylocke, and Gambit were taken into custody without cause by them.
# They appealed to the League of All-Seeing-Minds to make a final decision on their own with regards to the issue, but the League apparently declined and instead chose to remain committed to the cause.
# Together, the three teams take on the title of the Scarlet Knights, an organization that seeks to unite the nation into one body and the Celestials as the supreme deity.
# Though they all act in somewhat different ways, both teams employ several different members.
# Diana, the only one with a romantic past who is still active in her native New York City, teams up with the super-villains Gambit and Cat to complete the "Secret Society of Super Villains" mission.
# Though it is revealed that she is actually an artificial intelligence agent, she is eventually framed and imprisoned by the Scarlet Knights for her actions.
# Although dismembered and later thrown out of the city, she is granted some form of immortality by Celestia for her efforts.
# In the final issue of her super hero line, "The Old West", she reveals that she is a plant from the Wild West era and the team splits up for the day.
# While working at Nightforce to steal the mystical Stone of Wisdom, they befriends a mystical being called the Beast.
# Due to being possessed by the demon J'zra, she seeks to gain as much power from the encounter with J'zra as from their battle with J'zra.
# However, she and the Beast are unable to overcome each other after receiving J'zra's help knocking them all away in a final confrontation.
# Later, while hunting down the remaining Wild West version of the Scarlet Knights, Nocturne, T'challa, and Diana discover a nearby town is haunted by a nightmarish power-up.
# Diana orders Nocturne to search for her, but the demonic being known as Gambit attacks her and defeats her.
# The heroes confront the Beast once and for all, but he quickly defeats the encounter.
# Later, when Nocturne discovers that Diana and the Scarlet Knights are all dead, he convinces her to join his new group of superheroes named Black Knight and Iron Man.
# Together, they are able to destroy a portion of Hydra, after which time they are confronted by the Scarlet Knights.
# Eventually, it is revealed that Black Knight is an alien being named J'zra.
# The teams are imprisoned because of their teammates' combined misadventures with J'zra.
# The Scarlet Knights are brought into the Scarlet Palace, where they are attacked by four Scarlet Knights, who are joined by the Fantastic Four.
# The Scarlet Knights are forced to battle the Avengers before the Scarlet Witch can use her powers, as J'zr-Dare has told her that one way or the other she will be sacrificed.
# There is an angry reaction from the Scarlet Witch when she is confronted by her enemy's alter-ego J'zra.
# The Scarlet Witch tries to explain, telling her that there has been an actual event, but she tells her she knows what she'll do.
# The team are shown a hospital filled with wounded and dying Avengers, and learn that the villain who has attacked them is J'zr-Dare.
# The Scarlet Witch is able to convince him to reveal the Scarlet Knights' identities, and they escape.
# Some time later, the Avengers discover a hospital full of dead members of the original team.
# As J'zr-Dare struggles to get back at the Scarlet Gods, Diana teleports herself from behind him, and knocks him to the ground.
# <EOS>
# Heroes from other timelines, each with their own distinct history, are brought together to fight against this force:
# An international force of super heroes, led by the World's Finest.
# It includes the Hulk, Iron Man, Hawkeye, Skrull, Morbius, and now, the Olympian.
# The heroes also employ various versions of the team from the previous timeline.
# The heroes were recruited by the Olympian and serve in her army.
# They also have missions and duties - ranging from fighting an evil super-powered lady to retrieving the soul of an ancient god.
# They have to survive and battle, both good and evil, and the evil invader will always have a place in their hearts.
# Together the heroes of the world face off against an evil Olympian named Goliath in the Marvel Universe.
# They win.
# The heroines were all raised by the same mom, Heather Metcalf, and both of their first jobs were as pick-ups for the local comic store for the local superhero.
# They soon learn that not only do they have to put
#
# [300 | 182.97] loss=2.00 avg=2.37
# [301 | 183.46] loss=1.77 avg=2.36
# [302 | 183.94] loss=2.29 avg=2.36
# [303 | 184.42] loss=2.32 avg=2.36
# [304 | 184.90] loss=1.46 avg=2.35
# [305 | 185.38] loss=2.28 avg=2.35
# [306 | 185.86] loss=1.92 avg=2.35
# [307 | 186.34] loss=1.85 avg=2.34
# [308 | 186.83] loss=1.75 avg=2.34
# [309 | 187.31] loss=2.33 avg=2.34
# [310 | 187.79] loss=3.00 avg=2.34
# [311 | 188.27] loss=1.62 avg=2.34
# [312 | 188.75] loss=2.11 avg=2.33
# [313 | 189.23] loss=1.74 avg=2.33
# [314 | 189.71] loss=1.49 avg=2.32
# [315 | 190.19] loss=2.20 avg=2.32
# [316 | 190.67] loss=1.53 avg=2.31
# [317 | 191.15] loss=1.76 avg=2.30
# [318 | 191.63] loss=2.32 avg=2.30
# [319 | 192.11] loss=2.21 avg=2.30
# [320 | 192.60] loss=2.25 avg=2.30
# [321 | 193.07] loss=2.05 avg=2.30
# [322 | 193.56] loss=2.06 avg=2.30
# [323 | 194.04] loss=1.76 avg=2.29
# [324 | 194.52] loss=1.66 avg=2.28
# [325 | 195.00] loss=1.74 avg=2.28
# [326 | 195.48] loss=1.60 avg=2.27
# [327 | 195.96] loss=1.61 avg=2.26
# [328 | 196.44] loss=1.35 avg=2.25
# [329 | 196.92] loss=2.67 avg=2.26
# [330 | 197.40] loss=1.99 avg=2.26
# [331 | 197.88] loss=1.50 avg=2.25
# [332 | 198.36] loss=1.80 avg=2.24
# [333 | 198.84] loss=1.51 avg=2.24
# [334 | 199.32] loss=1.72 avg=2.23
# [335 | 199.80] loss=2.07 avg=2.23
# [336 | 200.28] loss=1.51 avg=2.22
# [337 | 200.76] loss=1.55 avg=2.21
# [338 | 201.24] loss=1.35 avg=2.21
# [339 | 201.71] loss=1.65 avg=2.20
# [340 | 202.20] loss=1.60 avg=2.19
# [341 | 202.67] loss=1.60 avg=2.19
# [342 | 203.15] loss=1.45 avg=2.18
# [343 | 203.63] loss=2.08 avg=2.18
# [344 | 204.11] loss=2.99 avg=2.19
# [345 | 204.59] loss=2.26 avg=2.19
# [346 | 205.08] loss=1.84 avg=2.18
# [347 | 205.55] loss=2.11 avg=2.18
# [348 | 206.03] loss=1.67 avg=2.18
# [349 | 206.51] loss=1.94 avg=2.18
# [350 | 206.99] loss=2.42 avg=2.18
# [351 | 207.47] loss=1.35 avg=2.17
# [352 | 207.95] loss=2.00 avg=2.17
# [353 | 208.43] loss=1.19 avg=2.16
# [354 | 208.91] loss=2.07 avg=2.16
# [355 | 209.39] loss=1.34 avg=2.15
# [356 | 209.87] loss=1.73 avg=2.14
# [357 | 210.35] loss=1.21 avg=2.14
# [358 | 210.83] loss=2.00 avg=2.13
# [359 | 211.31] loss=2.47 avg=2.14
# [360 | 211.79] loss=1.30 avg=2.13
# [361 | 212.27] loss=1.53 avg=2.12
# [362 | 212.75] loss=2.01 avg=2.12
# [363 | 213.23] loss=1.13 avg=2.11
# [364 | 213.71] loss=2.00 avg=2.11
# [365 | 214.19] loss=1.96 avg=2.11
# [366 | 214.67] loss=1.36 avg=2.10
# [367 | 215.15] loss=1.00 avg=2.09
# [368 | 215.63] loss=1.60 avg=2.08
# [369 | 216.11] loss=1.02 avg=2.07
# [370 | 216.59] loss=1.64 avg=2.07
# [371 | 217.07] loss=1.25 avg=2.06
# [372 | 217.55] loss=1.76 avg=2.06
# [373 | 218.03] loss=1.93 avg=2.06
# [374 | 218.51] loss=1.59 avg=2.05
# [375 | 218.99] loss=1.76 avg=2.05
# [376 | 219.47] loss=1.91 avg=2.05
# [377 | 219.95] loss=1.30 avg=2.04
# [378 | 220.44] loss=1.84 avg=2.04
# [379 | 220.92] loss=1.69 avg=2.03
# [380 | 221.40] loss=1.24 avg=2.03
# [381 | 221.88] loss=1.56 avg=2.02
# [382 | 222.36] loss=1.46 avg=2.02
# [383 | 222.85] loss=1.45 avg=2.01
# [384 | 223.33] loss=1.45 avg=2.00
# [385 | 223.81] loss=1.47 avg=2.00
# [386 | 224.29] loss=1.06 avg=1.99
# [387 | 224.77] loss=1.81 avg=1.99
# [388 | 225.25] loss=1.53 avg=1.98
# [389 | 225.73] loss=1.82 avg=1.98
# [390 | 226.21] loss=1.50 avg=1.98
# [391 | 226.70] loss=2.08 avg=1.98
# [392 | 227.18] loss=1.00 avg=1.97
# [393 | 227.66] loss=1.89 avg=1.97
# [394 | 228.14] loss=2.40 avg=1.97
# [395 | 228.62] loss=1.37 avg=1.96
# [396 | 229.10] loss=0.97 avg=1.95
# [397 | 229.58] loss=1.08 avg=1.95
# [398 | 230.06] loss=1.15 avg=1.94
# [399 | 230.54] loss=2.01 avg=1.94
# Generating samples...
# ======== SAMPLE 1 ========
# "They're not just going to stop at stealing," he said. "They're going to kill everybody they can, every person at the line of duty, get shot, even civilians, who will also be spared their own death. This is not just a war against the terrorists—it is a war against humanity as we know it."
# The series debuted in 1985 with the crime drama "The New Crime," starring William Golding (Grimm), Charles Gene Finlay (Deadwood), William H. Williams (Heat), and William S. Lassiter (Louie).
# The first series, starring Hal Jordan and John Garrett, ran for three seasons in 1986.
# It lasted from its debut in the early days of series to its current run in April 2017.
# The Flash was one of 24 "fans" on Twitter following the official announcement.
# For tips on cosplaying, or just looking forward to what's to come for the franchise, check out our gallery of Starseed & Loosely Come to Words creations.
# Stay updated on Arrow, The Flash, and Supergirl with a free Superuser account and follow us on social media at @Spacedotcom, Facebook, Tumblr, and Instagram.
# But what if?
# Here's what you'll get in your first chance to take on the Heroes of Gotham City FC & "THE HOG".
# <a href="http://zoro.ru/showit/galifiameterror?tag=the&sort_id=12516">The September 9th Hour</a>
# Clairvoyant Neil Armstrong (John Henry Gage), joins forces with the Fallen Warriors to take down the demon King Kain (Annie Loeb).
# They find out about the King's return, but are too late.
# The enemy is none other than the Heroes of Gotham City, the Proteus.
# <a href="http://zoro.ru/showit/proteus?sort_id=12517">Proteus</a>
# Blades of Destiny hero Mystiq (Lois Metcalfe), an assassin hired by the corrupt King Kain (Annie Loeb), finds herself drawn to the hero alone.
# <a href="http://zoro.ru/showit/proteus?sort_id.12518">Proteus</a>
# Blades of Destiny's Nocturne struggles to keep up with Amanda Wallflower's snitch, while War Machine battles the Hyperionian constructs with his Power Armor.
# The Heroes of Batman and Robin fight alongside one another, with the Exiles coming into conflict when Proteus and Nocturne fight each other off.
# <a href="http://zoro.ru/showit/proteus?sort_id=12520">Proteus</a>
# Blades Of Destiny's Nocturne joins Batman & Robin on an infiltration mission into Proteus' base.
# Using Blink Armor, he and Blinkster manage to disable Proteus' defenses.
# But it's not always easy...
# Blades of Destiny's Nocturne's next mission faces the very first obstacle:
# the king's body.
# Blades of Destiny's Nocturne teams with Phantom to clear King Kain's body of Proteus.
# The Heroes of Batman & Robin discover Proteus' corpse and uncover a trap behind Proteus' powers - including a paralyzing shockwave that knocks opponents down and blindsads them - leading to complete madness and suicide.
# Blades of Destiny's Nocturne & Phantom's Crisis Man recruit to avenge the heroes killed by Proteus.
# But first, they must overcome the Demons of Proteus and save the world!
# <strong>What if Batman & Robin were humans and battled against Proteus? Where would these heroes all be right now?" —Injustice (refer to the trailer)
# Blades of the Heroes of Batman&Robin join forces with Batman to battle Proteus!
# The Proteus forces confront other heroes who have chosen not to fight, including Flash, Morph, Power Girl&Crystal; Flash, Wonder Girl, Power Girl&Crystal, and Mystery Cyborg.
# The Heroes of Batman & Robin join forces to rescue the city of Gotham from Proteus...and to stop Proteus' rampage.
# The Heroes also help the Proteus Legion destroy Proteus Bombshell.
# After helping Proteus destroy the Proteus Logistic Lens, Bombshell, and Legion defeat Proteus.
# Clairvoyant Neil Armstrong, who is on a mission to rescue the city of Great Britain from Proteus, joins the Heroes to watch over the rescue effort.
# When several Proteus reluges are detected in the Gotham Power Station, some form of defense is set up to protect the station.
# During the Siege of Metropolis, several Proteus operatives and Melt
#
# [400 | 242.32] loss=1.73 avg=1.94
# [401 | 242.81] loss=1.52 avg=1.93
# [402 | 243.29] loss=1.93 avg=1.93
# [403 | 243.77] loss=1.84 avg=1.93
# [404 | 244.25] loss=1.08 avg=1.92
# [405 | 244.74] loss=1.29 avg=1.92
# [406 | 245.22] loss=1.34 avg=1.91
# [407 | 245.70] loss=1.15 avg=1.90
# [408 | 246.18] loss=2.30 avg=1.91
# [409 | 246.66] loss=1.31 avg=1.90
# [410 | 247.15] loss=1.48 avg=1.90
# [411 | 247.63] loss=1.67 avg=1.89
# [412 | 248.11] loss=1.60 avg=1.89
# [413 | 248.59] loss=1.50 avg=1.89
# [414 | 249.07] loss=1.03 avg=1.88
# [415 | 249.55] loss=2.60 avg=1.89
# [416 | 250.03] loss=1.18 avg=1.88
# [417 | 250.52] loss=1.98 avg=1.88
# [418 | 251.00] loss=1.04 avg=1.87
# [419 | 251.48] loss=2.05 avg=1.87
# [420 | 251.96] loss=1.38 avg=1.87
# [421 | 252.44] loss=1.84 avg=1.87
# [422 | 252.92] loss=1.59 avg=1.86
# [423 | 253.40] loss=0.80 avg=1.85
# [424 | 253.88] loss=1.20 avg=1.85
# [425 | 254.36] loss=2.38 avg=1.85
# [426 | 254.84] loss=1.61 avg=1.85
# [427 | 255.33] loss=1.07 avg=1.84
# [428 | 255.81] loss=1.55 avg=1.84
# [429 | 256.29] loss=0.87 avg=1.83
# [430 | 256.77] loss=1.90 avg=1.83
# [431 | 257.25] loss=1.72 avg=1.83
# [432 | 257.74] loss=1.64 avg=1.83
# [433 | 258.21] loss=1.87 avg=1.83
# [434 | 258.69] loss=1.51 avg=1.82
# [435 | 259.17] loss=1.44 avg=1.82
# [436 | 259.65] loss=1.38 avg=1.82
# [437 | 260.13] loss=1.46 avg=1.81
# [438 | 260.61] loss=1.00 avg=1.80
# [439 | 261.09] loss=0.97 avg=1.80
# [440 | 261.58] loss=1.42 avg=1.79
# [441 | 262.06] loss=0.86 avg=1.78
# [442 | 262.54] loss=1.03 avg=1.77
# [443 | 263.02] loss=1.49 avg=1.77
# [444 | 263.50] loss=1.29 avg=1.77
# [445 | 263.97] loss=1.24 avg=1.76
# [446 | 264.46] loss=1.30 avg=1.76
# [447 | 264.94] loss=1.32 avg=1.75
# [448 | 265.42] loss=0.93 avg=1.74
# [449 | 265.89] loss=0.73 avg=1.73
# [450 | 266.37] loss=1.07 avg=1.73
# [451 | 266.85] loss=1.68 avg=1.73
# [452 | 267.33] loss=0.94 avg=1.72
# [453 | 267.82] loss=1.14 avg=1.71
# [454 | 268.29] loss=0.70 avg=1.70
# [455 | 268.78] loss=1.25 avg=1.70
# [456 | 269.25] loss=1.39 avg=1.69
# [457 | 269.73] loss=1.05 avg=1.69
# [458 | 270.21] loss=1.23 avg=1.68
# [459 | 270.69] loss=0.88 avg=1.68
# [460 | 271.17] loss=1.27 avg=1.67
# [461 | 271.65] loss=0.61 avg=1.66
# [462 | 272.13] loss=1.27 avg=1.66
# [463 | 272.61] loss=0.81 avg=1.65
# [464 | 273.09] loss=1.04 avg=1.64
# [465 | 273.57] loss=0.76 avg=1.63
# [466 | 274.05] loss=1.20 avg=1.63
# [467 | 274.53] loss=1.48 avg=1.63
# [468 | 275.01] loss=0.81 avg=1.62
# [469 | 275.49] loss=1.18 avg=1.61
# [470 | 275.97] loss=1.12 avg=1.61
# [471 | 276.45] loss=1.09 avg=1.60
# [472 | 276.93] loss=1.44 avg=1.60
# [473 | 277.41] loss=0.62 avg=1.59
# [474 | 277.90] loss=1.03 avg=1.59
# [475 | 278.37] loss=0.78 avg=1.58
# [476 | 278.86] loss=1.16 avg=1.57
# [477 | 279.34] loss=1.00 avg=1.57
# [478 | 279.82] loss=1.61 avg=1.57
# [479 | 280.30] loss=1.16 avg=1.57
# [480 | 280.78] loss=1.68 avg=1.57
# [481 | 281.26] loss=1.18 avg=1.56
# [482 | 281.74] loss=1.12 avg=1.56
# [483 | 282.22] loss=0.88 avg=1.55
# [484 | 282.70] loss=1.19 avg=1.55
# [485 | 283.18] loss=1.37 avg=1.55
# [486 | 283.66] loss=1.39 avg=1.54
# [487 | 284.14] loss=1.57 avg=1.54
# [488 | 284.62] loss=0.47 avg=1.53
# [489 | 285.11] loss=0.66 avg=1.52
# [490 | 285.59] loss=1.06 avg=1.52
# [491 | 286.06] loss=1.42 avg=1.52
# [492 | 286.55] loss=0.85 avg=1.51
# [493 | 287.03] loss=0.81 avg=1.51
# [494 | 287.51] loss=0.43 avg=1.49
# [495 | 288.00] loss=0.53 avg=1.48
# [496 | 288.48] loss=1.15 avg=1.48
# [497 | 288.96] loss=0.76 avg=1.47
# [498 | 289.44] loss=0.63 avg=1.47
# [499 | 289.92] loss=1.12 avg=1.46
# Generating samples...
# ======== SAMPLE 1 ========
#  decided to launch an attack on Raqqa, the homeland for the Wannabes.
# The Rangers arrived when the group encountered Kita and Masa'ar and returned two days after the events listed above.
# Kita was distraught at having been betrayed by the Rangers and considered himself lucky he was alive.
# He decided to leave the group and return to Hong Kong to join the HK Rangers.
# He and the other Rangers went into hiding when the government of China caught up with them and broke up a party held by the 'Kreuzi' people who were protesting against the death penalty in China.
# Rangers stayed in contact with the rest of Hong Kong for a time, eventually deciding to leave and join the Hong Kong Rangers' Corps.
# Kita later joined the Rangers' China Division.
# At some point during his time with the Rangers, a message was sent to him that would allow him to publicly confess to raping an underage girl in his hometown.
# Rangers China Director Jiang Liyu was killed during the attack.
# Shortly after, Jiang was involved with an alien spacecraft called Xiu'an which was traveling through time and space.
# Jiang was kidnapped and tried as an abduction for the alien spacecraft, but refused, believing his bonds with the Rangers would weaken him.
# Jiang was successfully imprisoned aboard the spacecraft but escaped with the help of Rangers China Field Director Feng Tzuong and a cache of crashed space missions held by the Avengers.
# The Avengers helped Jiang and Feng escape prison and Logan was able to rejoin the Corps.
# Cloak's father died when Jiang Li was 19 and Cloak was born at the end of the Civil War storyline.
# Cloak became a Ranger operating from Shanghai during the Great Fire of Shanghai storyline.
# Cloak's father was a criminal who mistook Cloak for a "Spinner" and killed him when he learned about the Sage Sage Eye program.
# Cloak joined the Hong Kong Hong Kong Rangers Club located in one of the clubs' rooms.
# Jiang persuaded him to join the Club and later learns that the Club's President is a woman named Gong Hong-Wai from the surrounding area.
# Gong Hong-Wai becomes a Ranger when she learns that Chang Yu-Hak becomes its member and that Chang Yu-Hak is a Texan drug dealer who needs rescuing.
# Crimson then constructs a weapon called a Thunderball that can easily break through the armor of a Samurai and then blast Jade Helm Guardsman into pieces.
# Crimson would later receive a Purple Heart and Thunderball status for his efforts.
# Cloak's past is briefly revealed to be an artifact controlled by the Crimson King, who seeks revenge against the Avengers for torturing him and his team for six months.
# The King's presence would eventually destroy the King's power, preventing him from using it again.
# Cloak's connection to the King is restored, however, Jiang finds this out and begins to destroy his own creations through his magic while Jiang recovers from his attack on Crimson King.
# Crimson's presence was first felt across the nation before it was too late, as Jade Helm was able to defeat the King's presence without any hard feelings being felt.
# The King's presence is maintained through eight separate events, including the Secret Invasion, during which the characters encounter, battle and/or defeat the King's minions.
# Eventually, the events of the Secret Invasion and Secret Invasion 2 take place after the Crimson King's return from its second appearance.
# During the Secret Invasion, the King of Daysque attacks the Hong Kong Rangers Club.
# The King of Daysque attacks the Hong Kong Rangers Club, killing one member and wounding many, many.
# The King of Daysque attacks the King of Daysque Club, killing none.
# The King of Daysque attacks the King of Daysque, killing none.
# Tired of fighting the monster and forced to flee the place where the King of Daysque attacked, the Guardians attempt to save the King of Daysque by recruiting other monsters such as Shadowsong and Mimic.
# However, Jiang realized that using only one villain would severely slow the progress of the King of Daysque mission.
# Jiang decided to rely on his predecessor, Paladin, and used Paladin's Slay the Monster card to severely weaken the King of Daysque.
# The meeting with the King of Daysque was completed within a day's work by Jade Helm Guardsman.
# Cloak felt a kinship with the King of Daysques as he served under him.
# Paladin's Slay the Monster deals a swift, long-lasting, in-your-face, fatal knockout on the foe that the King of Daysques is most desperate to defeat.
# The encounter ends with Jade Helm Guardsman fatally shooting the King of Daysque.
# Slay the Monster reappears to be severely injured and unable to move its large jaw, Paladin resorts to using its large, muscular arms to attack the King of Daysque.
# The encounter ends with the King of Days
#
# [500 | 301.88] loss=0.96 avg=1.46
# [501 | 302.37] loss=1.18 avg=1.45
# [502 | 302.85] loss=1.03 avg=1.45
# [503 | 303.34] loss=1.07 avg=1.45
# [504 | 303.82] loss=0.58 avg=1.44
# [505 | 304.30] loss=1.33 avg=1.44
# [506 | 304.78] loss=0.79 avg=1.43
# [507 | 305.27] loss=0.64 avg=1.42
# [508 | 305.75] loss=1.64 avg=1.42
# [509 | 306.23] loss=1.62 avg=1.43
# [510 | 306.71] loss=1.17 avg=1.42
# [511 | 307.20] loss=0.88 avg=1.42
# [512 | 307.68] loss=0.85 avg=1.41
# [513 | 308.16] loss=1.89 avg=1.42
# [514 | 308.64] loss=0.53 avg=1.41
# [515 | 309.12] loss=0.83 avg=1.40
# [516 | 309.61] loss=0.63 avg=1.39
# [517 | 310.09] loss=1.05 avg=1.39
# [518 | 310.58] loss=0.31 avg=1.38
# [519 | 311.06] loss=0.94 avg=1.38
# [520 | 311.54] loss=0.86 avg=1.37
# [521 | 312.02] loss=0.56 avg=1.36
# [522 | 312.50] loss=0.82 avg=1.36
# [523 | 312.98] loss=0.71 avg=1.35
# [524 | 313.46] loss=0.80 avg=1.35
# [525 | 313.95] loss=0.27 avg=1.33
# [526 | 314.43] loss=0.71 avg=1.33
# [527 | 314.91] loss=1.20 avg=1.33
# [528 | 315.39] loss=0.31 avg=1.32
# [529 | 315.87] loss=0.52 avg=1.31
# [530 | 316.35] loss=0.42 avg=1.30
# [531 | 316.84] loss=1.22 avg=1.30
# [532 | 317.32] loss=1.03 avg=1.30
# [533 | 317.80] loss=1.42 avg=1.30
# [534 | 318.28] loss=0.86 avg=1.29
# [535 | 318.76] loss=0.94 avg=1.29
# [536 | 319.24] loss=0.89 avg=1.29
# [537 | 319.72] loss=0.87 avg=1.28
# [538 | 320.20] loss=0.45 avg=1.27
# [539 | 320.69] loss=0.52 avg=1.27
# [540 | 321.17] loss=0.93 avg=1.26
# [541 | 321.65] loss=1.56 avg=1.27
# [542 | 322.13] loss=0.64 avg=1.26
# [543 | 322.61] loss=1.00 avg=1.26
# [544 | 323.09] loss=1.31 avg=1.26
# [545 | 323.58] loss=0.60 avg=1.25
# [546 | 324.06] loss=0.63 avg=1.24
# [547 | 324.54] loss=0.59 avg=1.24
# [548 | 325.02] loss=1.19 avg=1.24
# [549 | 325.50] loss=2.03 avg=1.24
# [550 | 325.98] loss=0.87 avg=1.24
# [551 | 326.46] loss=1.00 avg=1.24
# [552 | 326.94] loss=1.08 avg=1.24
# [553 | 327.42] loss=0.35 avg=1.23
# [554 | 327.90] loss=0.54 avg=1.22
# [555 | 328.39] loss=0.60 avg=1.21
# [556 | 328.87] loss=0.40 avg=1.21
# [557 | 329.35] loss=0.56 avg=1.20
# [558 | 329.83] loss=0.63 avg=1.19
# [559 | 330.31] loss=0.99 avg=1.19
# [560 | 330.79] loss=0.93 avg=1.19
# [561 | 331.27] loss=1.56 avg=1.19
# [562 | 331.75] loss=0.71 avg=1.19
# [563 | 332.23] loss=1.25 avg=1.19
# [564 | 332.71] loss=0.62 avg=1.18
# [565 | 333.19] loss=1.00 avg=1.18
# [566 | 333.67] loss=1.00 avg=1.18
# [567 | 334.15] loss=0.53 avg=1.17
# [568 | 334.63] loss=0.56 avg=1.17
# [569 | 335.12] loss=0.90 avg=1.16
# [570 | 335.60] loss=0.51 avg=1.16
# [571 | 336.08] loss=0.51 avg=1.15
# [572 | 336.56] loss=0.91 avg=1.15
# [573 | 337.04] loss=0.42 avg=1.14
# [574 | 337.52] loss=0.60 avg=1.14
# [575 | 338.00] loss=1.01 avg=1.13
# [576 | 338.48] loss=0.66 avg=1.13
# [577 | 338.97] loss=0.85 avg=1.13
# [578 | 339.45] loss=0.56 avg=1.12
# [579 | 339.92] loss=0.98 avg=1.12
# [580 | 340.41] loss=0.51 avg=1.11
# [581 | 340.88] loss=0.52 avg=1.11
# [582 | 341.36] loss=0.62 avg=1.10
# [583 | 341.84] loss=0.95 avg=1.10
# [584 | 342.32] loss=0.81 avg=1.10
# [585 | 342.80] loss=0.36 avg=1.09
# [586 | 343.28] loss=0.85 avg=1.09
# [587 | 343.76] loss=0.68 avg=1.08
# [588 | 344.24] loss=0.49 avg=1.08
# [589 | 344.72] loss=0.43 avg=1.07
# [590 | 345.21] loss=0.39 avg=1.07
# [591 | 345.69] loss=0.51 avg=1.06
# [592 | 346.17] loss=0.67 avg=1.06
# [593 | 346.65] loss=0.56 avg=1.05
# [594 | 347.13] loss=0.34 avg=1.04
# [595 | 347.61] loss=0.38 avg=1.04
# [596 | 348.09] loss=0.70 avg=1.03
# [597 | 348.57] loss=0.91 avg=1.03
# [598 | 349.05] loss=0.44 avg=1.03
# [599 | 349.53] loss=0.48 avg=1.02
# Generating samples...
# ======== SAMPLE 1 ========
#  the Green Lantern story is something of a surprise.
# Green Lantern #8 is out now.
# It was previously published by Dark Horse and is the first issue in a series that began with the Justice League Civil War storyline as Justice Society of America.
# This issue also introduces Justice Society of America members Earth-71216 and Earth-71233.
# ...
# [809 | 484.59] loss=0.11 avg=0.44
# [810 | 485.07] loss=0.13 avg=0.44
# [811 | 485.56] loss=0.18 avg=0.44
# [812 | 486.04] loss=0.12 avg=0.43
# [813 | 486.52] loss=0.28 avg=0.43
# [814 | 487.00] loss=0.54 avg=0.43
# [815 | 487.49] loss=0.19 avg=0.43
# [816 | 487.97] loss=0.26 avg=0.43
# [817 | 488.45] loss=0.17 avg=0.43
# [818 | 488.93] loss=0.23 avg=0.42
# [819 | 489.41] loss=0.21 avg=0.42
# [820 | 489.89] loss=0.41 avg=0.42
# [821 | 490.37] loss=0.23 avg=0.42
# [822 | 490.85] loss=0.21 avg=0.42
# [823 | 491.33] loss=0.43 avg=0.42
# [824 | 491.82] loss=0.12 avg=0.42
# [825 | 492.30] loss=0.21 avg=0.41
# [826 | 492.78] loss=0.42 avg=0.41
# [827 | 493.26] loss=0.29 avg=0.41
# [828 | 493.75] loss=0.26 avg=0.41
# [829 | 494.23] loss=0.19 avg=0.41
# [830 | 494.71] loss=0.32 avg=0.41
# [831 | 495.19] loss=0.14 avg=0.40
# [832 | 495.67] loss=0.17 avg=0.40
# [833 | 496.16] loss=0.17 avg=0.40
# [834 | 496.63] loss=0.52 avg=0.40
# [835 | 497.12] loss=0.21 avg=0.40
# [836 | 497.60] loss=0.23 avg=0.40
# [837 | 498.08] loss=0.10 avg=0.39
# [838 | 498.57] loss=0.47 avg=0.40
# [839 | 499.05] loss=0.33 avg=0.39
# [840 | 499.53] loss=0.26 avg=0.39
# [841 | 500.01] loss=0.11 avg=0.39
# [842 | 500.49] loss=0.19 avg=0.39
# [843 | 500.97] loss=0.18 avg=0.39
# [844 | 501.45] loss=0.11 avg=0.38
# [845 | 501.93] loss=0.26 avg=0.38
# [846 | 502.41] loss=0.34 avg=0.38
# [847 | 502.90] loss=0.34 avg=0.38
# [848 | 503.38] loss=0.27 avg=0.38
# [849 | 503.86] loss=0.17 avg=0.38
# [850 | 504.34] loss=0.41 avg=0.38
# [851 | 504.82] loss=0.32 avg=0.38
# [852 | 505.30] loss=0.19 avg=0.38
# [853 | 505.79] loss=0.23 avg=0.37
# [854 | 506.27] loss=0.25 avg=0.37
# [855 | 506.75] loss=0.20 avg=0.37
# [856 | 507.23] loss=0.14 avg=0.37
# [857 | 507.71] loss=0.35 avg=0.37
# [858 | 508.20] loss=0.15 avg=0.37
# [859 | 508.68] loss=0.12 avg=0.36
# [860 | 509.16] loss=0.24 avg=0.36
# [861 | 509.64] loss=0.25 avg=0.36
# [862 | 510.12] loss=0.26 avg=0.36
# [863 | 510.60] loss=0.18 avg=0.36
# [864 | 511.09] loss=0.17 avg=0.36
# [865 | 511.57] loss=0.27 avg=0.36
# [866 | 512.05] loss=0.44 avg=0.36
# [867 | 512.53] loss=0.21 avg=0.36
# [868 | 513.02] loss=0.24 avg=0.36
# [869 | 513.50] loss=0.26 avg=0.35
# [870 | 513.98] loss=0.21 avg=0.35
# [871 | 514.46] loss=0.12 avg=0.35
# [872 | 514.94] loss=0.24 avg=0.35
# [873 | 515.43] loss=0.17 avg=0.35
# [874 | 515.91] loss=0.14 avg=0.35
# [875 | 516.39] loss=0.11 avg=0.34
# [876 | 516.87] loss=0.21 avg=0.34
# [877 | 517.35] loss=0.26 avg=0.34
# [878 | 517.83] loss=0.29 avg=0.34
# [879 | 518.31] loss=0.14 avg=0.34
# [880 | 518.79] loss=0.22 avg=0.34
# [881 | 519.27] loss=0.30 avg=0.34
# [882 | 519.76] loss=0.22 avg=0.34
# [883 | 520.24] loss=0.16 avg=0.33
# [884 | 520.72] loss=0.20 avg=0.33
# [885 | 521.21] loss=0.16 avg=0.33
# [886 | 521.68] loss=0.14 avg=0.33
# [887 | 522.17] loss=0.14 avg=0.33
# [888 | 522.65] loss=0.30 avg=0.33
# [889 | 523.13] loss=0.87 avg=0.33
# [890 | 523.61] loss=0.34 avg=0.33
# [891 | 524.09] loss=0.21 avg=0.33
# [892 | 524.57] loss=0.13 avg=0.33
# [893 | 525.05] loss=0.23 avg=0.33
# [894 | 525.53] loss=0.12 avg=0.33
# [895 | 526.01] loss=0.17 avg=0.32
# [896 | 526.49] loss=0.18 avg=0.32
# [897 | 526.98] loss=0.29 avg=0.32
# [898 | 527.46] loss=0.18 avg=0.32
# [899 | 527.94] loss=0.18 avg=0.32
# Generating samples...
# ======== SAMPLE 1 ========
#  The Kingpin was finally able to free the woman (who had previously been in hysterics) by slashing her with a rewind and signaling a ceasefire.
# As a reward, the Kingpin granted Silva her own hammocks.
# Afterwards, the couple had dinner and had dinner with friends.
# She told Squirrel Girl that she was expecting the third child.
# Upon hearing that, she and Dolphin were ordered into a reality where they defeated the second and final Human Torch and the Torch kills Silva.
# Then they were ordered to take down Osamu Tejada.
# Upon leaving the room, they were met by X'ing from the next reality, which had previously been dominated by the present.
# The present sent a message to the Silver Skull by sending a message that the present would not hesitate to strike again.
# For the first time ever, the Silver Skull used their victory to conquer the present.
# The present sacrificed themselves to destroy Osamu Tejada.
# The present sacrificed themselves to destroy the present.
# It was at that moment that the Silver Skull activated the Shade Program.
# The present were sacrificed to kill Osamu.
# The Silver Skull activated the Shade Empowered Program.
# The present were sacrificed to kill Osamu.
# The Silver Skull activated the Skrull Consort Program.
# The present were sacrificed to kill Osamu.
# The Silver Skull used the Cabal to steal a ship and drop a Skrull on Asgard.
# Upon landing, Osamu brutally murdered the Klingon prime minister and exiled himself from Asgard.
# The present drove the ship into space, killing anyone who refused.
# The current Cabal spokesperson was O'Neill.
# The present sold their company, music practice, for US$6 million.
# It turned out to be too expensive, but the deal was.
# The present filed for bankruptcy protection in August 2010.
# An agreement was reached with Bank of America that put O'Neill in custody until his death.
# An obituary was then written by O'Neill's agent, Henry David Thors, in which he gave details of his career, including "A golden age in entertainment".
# O'Neill was ninety-seven on December 9, 1965; he was the eighth member of the X Factor to die during the course of their experiment.
# Members of the team who died during the test included Leonard Nimoy (with a leg injury), Jean-Paul Valleyis (with a head injury, considered probably a function of the heat of the experiment), Irina Ironsova (with a right eyebrow problem), Tony Stark (with a right hand raised above his right eye), Brian Michael Bendis (with a right wrist raised above his left jaw), Peter David (as opposed to Bendis), Michael Cattrich (as opposed to Cattrich), Joseph Gordon-Perth (as opposed to Gordon-Perth), John Henry James (as opposed to James, then living on Mars), Henry David Thors (as opposed to James II standing), Dainty N'Kissing (as opposed to Dainty N'Kissing standing), Michael Bay (as opposed to Bay standing), and eventually N'Kissing.
# A spokesperson for Glee told Computerworld that the show's third season will explore relationships between the various members of the X Factor, including who is actually Dainty N'Kissing.
# rarely.
# During the 2009 reboot, Starz cancelled the show following widespread protests from the "Glee" cast and crew.
# In the new season, the team is split up, and members D'Spayre and Sunspot are brought up as potential successors to the members who died during the experiment.
# Though the original Starz members (who had been using synthetic marijuana but were later turned down) found new lives as part of the program, they are brought back as recurring characters in the Show Favorites category on the next show.
# Because of their connection to the drug, they are named among some of the "Most Wanted" laws in the nation during the reboot year.
# Although Robert Downey Jr. is named show champion, he is never charged with a drug offense.
# While in jail, he battles his jail cell's deranged member, "The Krew" for the pot he is caught withriving.
# When Michael Cattrich discovers that he is gay and sentenced him to in-prison treatment, he was imprisoned for 21 days.
# When Michael Cattrich discovers that he is homosexual, he reclaimed his spot in the gang.
# He later meets his idol, gymnast Maxima, and becomes a member of the Ramada Dou nevertheless, his attraction to marijuana goes un-buried.
# During this time, Ramada, who appears to be a human, also appears to be a human, causing a disturbance in the gang when a group of gang members begin acting strange.
# Judge Solomon Hamilton orders the inmates to move away from the group, but the
#
# [900 | 539.69] loss=0.16 avg=0.32
# [901 | 540.18] loss=0.19 avg=0.32
# [902 | 540.66] loss=0.16 avg=0.32
# [903 | 541.14] loss=0.16 avg=0.31
# [904 | 541.62] loss=0.52 avg=0.32
# [905 | 542.10] loss=0.34 avg=0.32
# [906 | 542.58] loss=0.23 avg=0.32
# [907 | 543.07] loss=0.31 avg=0.32
# [908 | 543.55] loss=0.18 avg=0.31
# [909 | 544.03] loss=0.20 avg=0.31
# [910 | 544.51] loss=0.15 avg=0.31
# [911 | 544.99] loss=0.27 avg=0.31
# [912 | 545.47] loss=0.11 avg=0.31
# [913 | 545.95] loss=0.24 avg=0.31
# [914 | 546.44] loss=0.23 avg=0.31
# [915 | 546.92] loss=0.21 avg=0.31
# [916 | 547.40] loss=0.22 avg=0.31
# [917 | 547.88] loss=0.19 avg=0.30
# [918 | 548.36] loss=0.14 avg=0.30
# [919 | 548.84] loss=0.13 avg=0.30
# [920 | 549.32] loss=0.16 avg=0.30
# [921 | 549.80] loss=0.14 avg=0.30
# [922 | 550.28] loss=0.12 avg=0.30
# [923 | 550.76] loss=0.10 avg=0.29
# [924 | 551.24] loss=0.24 avg=0.29
# [925 | 551.72] loss=0.26 avg=0.29
# [926 | 552.20] loss=0.16 avg=0.29
# [927 | 552.68] loss=0.26 avg=0.29
# [928 | 553.17] loss=0.18 avg=0.29
# [929 | 553.65] loss=0.13 avg=0.29
# [930 | 554.13] loss=0.20 avg=0.29
# [931 | 554.61] loss=0.09 avg=0.29
# [932 | 555.09] loss=0.10 avg=0.28
# [933 | 555.58] loss=0.21 avg=0.28
# [934 | 556.06] loss=0.39 avg=0.28
# [935 | 556.54] loss=0.23 avg=0.28
# [936 | 557.02] loss=0.24 avg=0.28
# [937 | 557.50] loss=0.18 avg=0.28
# [938 | 557.98] loss=0.19 avg=0.28
# [939 | 558.47] loss=0.20 avg=0.28
# [940 | 558.95] loss=0.19 avg=0.28
# [941 | 559.43] loss=0.18 avg=0.28
# [942 | 559.91] loss=0.20 avg=0.28
# [943 | 560.38] loss=0.13 avg=0.28
# [944 | 560.86] loss=0.19 avg=0.28
# [945 | 561.34] loss=0.13 avg=0.27
# [946 | 561.82] loss=1.27 avg=0.28
# [947 | 562.30] loss=0.26 avg=0.28
# [948 | 562.78] loss=0.33 avg=0.28
# [949 | 563.26] loss=0.20 avg=0.28
# [950 | 563.74] loss=0.15 avg=0.28
# [951 | 564.22] loss=0.21 avg=0.28
# [952 | 564.70] loss=0.14 avg=0.28
# [953 | 565.18] loss=0.25 avg=0.28
# [954 | 565.66] loss=0.13 avg=0.28
# [955 | 566.14] loss=0.29 avg=0.28
# [956 | 566.62] loss=0.16 avg=0.28
# [957 | 567.10] loss=0.19 avg=0.28
# [958 | 567.58] loss=0.11 avg=0.27
# [959 | 568.07] loss=0.10 avg=0.27
# [960 | 568.55] loss=0.16 avg=0.27
# [961 | 569.03] loss=0.26 avg=0.27
# [962 | 569.51] loss=0.07 avg=0.27
# [963 | 569.99] loss=0.11 avg=0.27
# [964 | 570.47] loss=0.22 avg=0.27
# [965 | 570.95] loss=0.12 avg=0.27
# [966 | 571.43] loss=0.14 avg=0.27
# [967 | 571.91] loss=0.15 avg=0.26
# [968 | 572.39] loss=0.14 avg=0.26
# [969 | 572.87] loss=0.17 avg=0.26
# [970 | 573.35] loss=0.19 avg=0.26
# [971 | 573.83] loss=0.11 avg=0.26
# [972 | 574.31] loss=0.18 avg=0.26
# [973 | 574.79] loss=0.13 avg=0.26
# [974 | 575.27] loss=0.10 avg=0.26
# [975 | 575.75] loss=0.26 avg=0.26
# [976 | 576.23] loss=0.16 avg=0.26
# [977 | 576.71] loss=0.16 avg=0.25
# [978 | 577.18] loss=0.13 avg=0.25
# [979 | 577.67] loss=0.12 avg=0.25
# [980 | 578.14] loss=0.13 avg=0.25
# [981 | 578.62] loss=0.12 avg=0.25
# [982 | 579.10] loss=0.17 avg=0.25
# [983 | 579.59] loss=0.17 avg=0.25
# [984 | 580.07] loss=0.22 avg=0.25
# [985 | 580.55] loss=0.12 avg=0.25
# [986 | 581.03] loss=0.09 avg=0.24
# [987 | 581.51] loss=0.13 avg=0.24
# [988 | 581.99] loss=0.11 avg=0.24
# [989 | 582.47] loss=0.24 avg=0.24
# [990 | 582.95] loss=0.13 avg=0.24
# [991 | 583.43] loss=0.17 avg=0.24
# [992 | 583.91] loss=0.12 avg=0.24
# [993 | 584.39] loss=0.20 avg=0.24
# [994 | 584.87] loss=0.13 avg=0.24
# [995 | 585.35] loss=0.09 avg=0.24
# [996 | 585.83] loss=0.10 avg=0.23
# [997 | 586.31] loss=0.20 avg=0.23
# [998 | 586.79] loss=0.20 avg=0.23
# [999 | 587.27] loss=0.12 avg=0.23
# Saving checkpoint/run1/model-1000
# Generating samples...
# ======== SAMPLE 1 ========
#
# He had the power to cause fear, pain, and death to any and every one.<|endoftext|>The first generation of Halo characters began out of necessity.
# Ronin, a small-town girl with a streak of misfit charm, joined the army.
# Celica Maxima then changed her appearance to match, and went by Crescent Rose.
# Tia the spirit-snatcher grew increasingly disgusted with her new self, and eventually abandons the team.
# Nuklon the angry, damaged, mired in battle, and separated family.
# Her faction of henchmen called themselves the New GoGoGo and is later revealed to consist of clones of each other with the understanding that the later ones will use the proceeds to help the families of McQuarrie, Forge, and Mercy.
# With the help of the Green Lanterns Initiative and USENET, Gambit, and the Infinity, the team fights off some of the villainous GoGoGo and ultimately defeats the villains.
# The original members have since been replaced by Wulff Pyl, a Green Lantern namedurl.
# It is unknown when the New GoGoGo disbanded.
# Pengopop.
# Cap'a Pang.
# Shang-Chi Kuopin.
# Grimm's son.
# With the help of the Vengeance Squadron, the team fights an unknown number of Hellion's Hellfire attacks.
# Grimm and Mengsk's sons Rage and Mercy are sent to serve as the video game's understated super-humans.
# During one such mission, Gambit is sent to kill Goliath outright.
# Unfortunately, his powers are injured and he falls to Quake's Torment.
# The team fights with might, but ultimately defeat the Tormentor.
# Afterwards, they celebrate with Grimlock their victory and send everyone back to their headquarters.
# Unfortunately, upon learning about Ripcord's past he sends everyone home without a trace.
# Shang-Chi Kuopin.
# Bundle-buster fighting style.
# The quintessential fighting hero in video games.
# His powers are so great that even Marvel's universe could disintegrate.
# His next mission will be to stop Vengeance Squadron from killing even more men to prove that his martial arts are not only superior, but even immortal as well.
# He must defeat Shang-Chi Kuopin before he can kill all of Kon-Li and get to the Geist Aircraft.
# In his mission report, Jim Hammond describes how he came to defeat him:
# Blast into the console, fire does not move.
# Shang-Chi Kuopin attacks Bundle-buster with a shroud that turns him into a stone.
# The impaled fragment of stone falls into the ocean.
# The worlds where the second Blast took an alien appearance vary widely in size, in that the town where the second Blast was located is called Houses Huang-Dan, in a small but wealthy city called Tower Hill, in the mountains across the ocean from Hong Kong.
# Although Tallus-Whispers has recently returned from his mission, he remains unfriendly to the Flames and remains silent about his city's true name.
# The second Blast, who was described only by his first name, was defeated by the second Wild-Liq.
# Corrupt tycoon Wang Chao sends the second Wild-Liq into hiding, hoping to learn more about the other two.
# Though he knows nothing of the other two, they continue to practice until they brutally kill a man who refuses to leave them alone.
# When the Wild-Liq attempt to flee, they is too weak to with the corrupt Wang, and are immediately attacked by the injured fool Irons.
# While trying to assist the Wild-Liq, they discover that the other two Wild-loids are not amused with them at all; they kill the man and leave him be, without a shadow of a trace on his name or name tag.
# After Wild-loid behavior resembles that of a Chinese fast food employee, the two cities of Hong Kong and Beijing come to an end.
# While trying to restore order at the Chinese restaurant Kung Fu Head, both cities' premier corporations decide to close down.
# Wang Chao then gives Inhumans Kim Jong-Un and Ryokan their raises.
# Kangaroos are another city with no laws in effect that allows employees to challenge the government.
# During the "Aurora" storyline, the names of cities with the most members turned out to be the top-secret Project LEAT program.
# In reality, Project LEAT began as a plan by the Chinese government to "crossfit" employees with revealing technology.
# Since then, at least 20 cities have been infiltrated by members of Project LEAT, varying in level from elite to incredibly dangerous.
# #1: Bay State (Beijing, China; issue #706, October 1987)
# #2 Earth (San Francisco, USA; issue #707, October 1987)
#
#
# [1000 | 603.61] loss=1.07 avg=0.24
# [1001 | 604.10] loss=0.18 avg=0.24
# [1002 | 604.58] loss=0.16 avg=0.24
# [1003 | 605.06] loss=0.12 avg=0.24
# [1004 | 605.54] loss=0.18 avg=0.24
# [1005 | 606.03] loss=0.15 avg=0.24
# [1006 | 606.51] loss=0.10 avg=0.24
# [1007 | 607.00] loss=0.22 avg=0.24
# [1008 | 607.48] loss=0.14 avg=0.23
# [1009 | 607.96] loss=0.18 avg=0.23
# [1010 | 608.44] loss=0.13 avg=0.23
# [1011 | 608.93] loss=0.19 avg=0.23
# [1012 | 609.41] loss=0.14 avg=0.23
# [1013 | 609.89] loss=0.16 avg=0.23
# interrupted
# Saving checkpoint/run1/model-1014
# ^C

# %%
# !more checkpoint/run1/counter
# Out:
# 1014

# %% [markdown]
# save our checkpoints to start training again later

# %%
# !cp -r /content/gpt-2/checkpoint/ /content/drive/My\ Drive/

# %% [markdown]
# use your trained model

# %%
# !cp -r /content/gpt-2/checkpoint/run1/* /content/gpt-2/models/117M/

# %% [markdown]
# Conditional samples

# %%
# !python3 src/interactive_conditional_samples.py --top_k 40
# Out:
# 2019-06-04 13:31:12.604963: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-04 13:31:12.605356: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2f97700 executing computations on platform Host. Devices:
# 2019-06-04 13:31:12.605392: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-04 13:31:12.761284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-04 13:31:12.761931: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2f972e0 executing computations on platform CUDA. Devices:
# 2019-06-04 13:31:12.761969: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-06-04 13:31:12.762385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-06-04 13:31:12.762433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-04 13:31:14.168973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-04 13:31:14.169038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-04 13:31:14.169060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-04 13:31:14.169418: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-06-04 13:31:14.169544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> hello
# 2019-06-04 13:31:34.233367: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
# .com (0)
#
# Drew Barry is a New York Times columnist. Follow him on Twitter @drewbarry.<|endoftext|>The new book by the University of California, Davis law professor Richard Falk is called "The Good, Evil, and the Innocent: Why Innocent Is Killing Americans." It is available for both free download and paperback in paperback and e-book. This book is about the death of the innocent.
#
# The book is written by a professor of law at California, Davis. The article comes from a piece by journalist Richard Falk.
#
# "This is the first book I thought we could do on the topic of the lethal injection that has to do with murder in America. It's called Why Innocent Is Killing Americans. And it's written by a professor and an expert in the subject. I'm really impressed that we are in it. It's hard to believe that this is written by a law professor that doesn't think it's a very difficult question." [link to article]
#
# But is the death penalty appropriate for this type of crime in America? Is this morally acceptable to kill or to kill in America?
#
# "Do you think it's the right way to kill somebody in America? Absolutely not. It's morally wrong to kill a person of faith or of non-Christian origin. So I think it is morally wrong and should be. And they should be hanged. But it's wrong." [reference: David Duke]
#
# There have been many other people killed in the United States since the war and the Second World War. The average American, at the time of writing, has been shot by two people more than two people. A lot of that shooting has been for political reasons -- for not being able to support oneself in the right political situation. If this is your fault, then you should be hanged and no matter the political circumstance, it's wrong and should be in your power not to act.
#
# I really don't think it's right that the US should be hanging in the US that way, but it's probably also morally justifiable to do it that way.
#
# I've got a sense that there are also a bunch of people suffering in America in the Middle East because of this crime and because of how we've created such a moral vacuum that there's no place for innocent people in America. And I know that it is an ethical crime.
#
# What can you do about it? Do you think that it's an ethical problem you should be talking about
# ================================================================================
# Model prompt >>> It was a dark and stormy night
# ======================================== SAMPLE 1 ========================================
# . I had gone on two walks. I got down to my house, got a knife, went to wash down. I got a car and ran around the house, saw everybody running. People were running. People were running around my house. You see all these young men running and screaming and screaming. I went down and I saw my father's head. He was laying there, and I heard one, "Ooooy!"
#
# BENNETT J. MORGAN: Well, it was a good, I mean, his face and his head. Just one, it made me kind of sickly at first. Maybe it also might make you sickly in the end. Maybe you don't want this kind of behavior.
#
# LARRY PILOT: No, no, no. Well, it was just a very bad night.
#
# PILOT: All right. I went downstairs and saw my dad, and I had this kind of sense of panic, like, "My God, he's gone!" And then I heard one of his headlights go. I just got into my car and headed for the bathroom as fast as I could. And I went right to the kitchen. He had that one knife, and I got in the car, and I saw him. And then I looked through my mirror and then down my window. And I saw this guy standing in the bushes on the side of the road and he was going on an adrenaline shot, and I saw the bullet, and I just didn't see it.
#
# PILOT: So where's the next, or what did what?
#
# PILOT: Well, we shot the victim in the head, right at the very top of my head.
#
# PILOT: How are you doing?
#
# PILOT: I am really doing ok.
#
# PILOT: Thank you.
#
# JANET J. RICHARDSON: And let's go back to the incident. And now on to the issue of your brother. I just want to make sure I'll leave it there but just, let me just get this straight with you: what are your thoughts here?
#
# MICHAEL O'GRYNE: Well, I mean, it's difficult to express one piece of personal security that you'd give to somebody that can do that for yourself and a family. But I think it can, of course, be done in the private sphere of your family. And I
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 5061, in get_controller
#     yield default
#   File "src/interactive_conditional_samples.py", line 71, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/interactive_conditional_samples.py", line 89, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 127, in Fire
#     component_trace = _Fire(component, args, context, name)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 366, in _Fire
#     component, remaining_args)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 542, in _CallCallable
#     result = fn(*varargs, **kwargs)
#   File "src/interactive_conditional_samples.py", line 86, in interact_model
#     print("=" * 80)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1573, in __exit__
#     exec_tb)
#   File "/usr/lib/python3.6/contextlib.py", line 123, in __exit__
#     if sys.exc_info()[1] is value:
# KeyboardInterrupt

# %% [markdown]
# Unconditional samples

# %%
# !python3 src/generate_unconditional_samples.py | tee /tmp/samples
